# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/county-cases-latest-master.csv").drop(columns={"Unnamed: 0"})

# %%
x = data["median_household_income"]
y = data["cases_per_100k"]

plt.scatter(x, y)

# %%
data.groupby(["state", "county"]).sum().corr()
# Out:
#                                                fips     cases    deaths  \
# fips                                       1.000000  0.175729  0.039866
# cases                                      0.175729  1.000000  0.928512
# deaths                                     0.039866  0.928512  1.000000
# population_est                             0.368888  0.744432  0.608061
# poverty_est_all_ages                       0.335410  0.721673  0.611955
# median_household_income                    0.357707  0.372949  0.273508
# less_than_high_school_diploma_2015-19      0.255278  0.822221  0.751701
# high_school_diploma_only_2015-19           0.347184  0.642800  0.530723
# some_college_or_associate_ degree_2015-19  0.374629  0.703965  0.557847
# bachelor_degree_or_higher_2015-19          0.335024  0.783699  0.681875
# cases_per_100k                             0.173080  0.226473  0.127204
#
#                                            population_est  \
# ...

# %%
data[data["state"] == "New York"][["median_household_income", "cases_per_100k"]].corr()
# Out:
#                          median_household_income  cases_per_100k
# median_household_income                 1.000000        0.710903
# cases_per_100k                          0.710903        1.000000
